# %%
import numpy as np
import pandas as pd 
import os 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\User\OneDrive - University of East London\Desktop\seattle-weather.csv")
data.shape
# Out:
# (1461, 6)

# %%
data.shape
# Out:
# (1461, 6)

# %%
from sklearn.preprocessing import MinMaxScaler

# Create a scaler object
scaler = MinMaxScaler()

# Select the columns to normalize
cols_to_normalize = ['precipitation', 'temp_max', 'temp_min','wind']

# Apply the scaler to the selected columns
data[cols_to_normalize] = scaler.fit_transform(data[cols_to_normalize])

# %%
data
# Out:
#             date  precipitation  temp_max  temp_min      wind  weather
# 0     2012-01-01       0.000000  0.387097  0.476378  0.472527  drizzle
# 1     2012-01-02       0.194991  0.327957  0.389764  0.450549     rain
# 2     2012-01-03       0.014311  0.357527  0.562992  0.208791     rain
# 3     2012-01-04       0.363148  0.370968  0.500000  0.472527     rain
# 4     2012-01-05       0.023256  0.282258  0.389764  0.626374     rain
# ...          ...            ...       ...       ...       ...      ...
# 1456  2015-12-27       0.153846  0.161290  0.346457  0.274725     rain
# 1457  2015-12-28       0.026834  0.177419  0.346457  0.098901     rain
# 1458  2015-12-29       0.000000  0.236559  0.303150  0.241758      fog
# 1459  2015-12-30       0.000000  0.193548  0.240157  0.329670      sun
# 1460  2015-12-31       0.000000  0.193548  0.196850  0.340659      sun
#
# [1461 rows x 6 columns]

# %%
data.shape
# Out:
# (1461, 6)

# %%
import warnings
warnings.filterwarnings('ignore')
sns.countplot("weather", data= data, palette= "hls")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import warnings
#       2 warnings.filterwarnings('ignore')
# ----> 3 sns.countplot("weather", data= data, palette= "hls")
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
countrain=len(data[data.weather=="rain"])
countsun=len(data[data.weather=="sun"])
countdrizzle=len(data[data.weather=="drizzle"])
countsnow=len(data[data.weather=="snow"])
countfog=len(data[data.weather=="fog"])
print("Percent of Rain:{:2f}%".format((countrain/(len(data.weather))*100)))
print("Percent of Sun:{:2f}%".format((countsun/(len(data.weather))*100)))
print("Percent of Drizzle:{:2f}%".format((countdrizzle/(len(data.weather))*100)))
print("Percent of Snow:{:2f}%".format((countsnow/(len(data.weather))*100)))
print("Percent of Fog:{:2f}%".format((countfog/(len(data.weather))*100)))

# %%
data[["precipitation","temp_max","temp_min","wind"]].describe()
# Out:
#        precipitation     temp_max     temp_min         wind
# count    1461.000000  1461.000000  1461.000000  1461.000000
# mean        0.054194     0.484922     0.603731     0.312213
# std         0.119503     0.197574     0.197756     0.158003
# min         0.000000     0.000000     0.000000     0.000000
# 25%         0.000000     0.327957     0.452756     0.197802
# 50%         0.000000     0.462366     0.606299     0.285714
# 75%         0.050089     0.639785     0.759843     0.395604
# max         1.000000     1.000000     1.000000     1.000000

# %%
sns.set(style="darkgrid")
fig,axs=plt.subplots(2,2,figsize=(10,8))
sns.histplot(data=data,x="precipitation",kde=True,ax=axs[0,0],color='green')
sns.histplot(data=data,x="temp_max",kde=True,ax=axs[0,1],color='red')
sns.histplot(data=data,x="temp_min",kde=True,ax=axs[1,0],color='skyblue')
sns.histplot(data=data,x="wind",kde=True,ax=axs[1,1],color='orange')
# Out:
# <Axes: xlabel='wind', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

# %%
sns.set(style="darkgrid")
fig,axs=plt.subplots(2,2,figsize=(10,8))
sns.histplot(data=data,x="precipitation",kde=True,ax=axs[0,0],color='green')
sns.histplot(data=data,x="temp_max",kde=True,ax=axs[0,1],color='red')
sns.histplot(data=data,x="temp_min",kde=True,ax=axs[1,0],color='skyblue')
sns.histplot(data=data,x="wind",kde=True,ax=axs[1,1],color='orange')
# Out:
# <Axes: xlabel='wind', ylabel='Count'>

# %%
sns.set(style="darkgrid")
fig,axs=plt.subplots(2,2,figsize=(10,8))
sns.violinplot(data=data,x="precipitation",kde=True,ax=axs[0,0],color='green')
sns.violinplot(data=data,x="temp_max",kde=True,ax=axs[0,1],color='red')
sns.violinplot(data=data,x="temp_min",kde=True,ax=axs[1,0],color='skyblue')
sns.violinplot(data=data,x="wind",kde=True,ax=axs[1,1],color='yellow')
# Out:
# <Axes: xlabel='wind'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot("wind","weather",data=data,palette="inferno")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 plt.figure(figsize=(12,6))
# ----> 2 sns.boxplot("wind","weather",data=data,palette="inferno")
#
# TypeError: boxplot() got multiple values for argument 'data'

# %%
plt.figure(figsize=(12,6))
sns.boxplot("temp_max","weather",data=data,palette="inferno")

# %%
plt.figure(figsize=(12,6))
sns.boxplot("precipitation","weather",data=data,palette="YlOrBr")

# %%
plt.figure(figsize=(12,6))
sns.boxplot("wind","weather",data=data,palette="inferno")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 plt.figure(figsize=(12,6))
# ----> 2 sns.boxplot("wind","weather",data=data,palette="inferno")
#
# TypeError: boxplot() got multiple values for argument 'data'

# %%
plt.figure(figsize=(12,6))
sns.boxplot("temp_min","weather",data=data,palette="YlOrBr")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 plt.figure(figsize=(12,6))
# ----> 2 sns.boxplot("temp_min","weather",data=data,palette="YlOrBr")
#
# TypeError: boxplot() got multiple values for argument 'data'

# %%
plt.figure(figsize=(12,7))
sns.heatmap(data.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
data.plot("precipitation","temp_max",style='o') 
print("Pearson correlation:",data["precipitation"].corr(data["temp_max"]))
print("T Test and P value:",stats.ttest_ind(data["precipitation"],data["temp_max"]))
# Out:
# Pearson correlation: -0.22855481643297004
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 data.plot("precipitation","temp_max",style='o')
#       2 print("Pearson correlation:",data["precipitation"].corr(data["temp_max"]))
# ----> 3 print("T Test and P value:",stats.ttest_ind(data["precipitation"],data["temp_max"]))
#
# NameError: name 'stats' is not defined

# %%
data.plot("precipitation","temp_max",style='o') 
print("Pearson correlation:",data["precipitation"].corr(data["temp_max"]))
print("T Test and P value:",stats.ttest_ind(data["precipitation"],data["temp_max"])
# Out:
#   Cell In[18], line 3
#     print("T Test and P value:",stats.ttest_ind(data["precipitation"],data["temp_max"])
#                                                                                        ^
# SyntaxError: incomplete input

# %%
import scipy
import re

from scipy import stats
from scipy.stats import ttest_ind
from scipy.stats import pearsonr

# %%
data.plot("precipitation","temp_max",style='o') 
print("Pearson correlation:",data["precipitation"].corr(data["temp_max"]))
print("T Test and P value:",stats.ttest_ind(data["precipitation"],data["temp_max"])
# Out:
#   Cell In[20], line 3
#     print("T Test and P value:",stats.ttest_ind(data["precipitation"],data["temp_max"])
#                                                                                        ^
# SyntaxError: incomplete input

# %%
data.plot("precipitation","temp_max",style='o') 
print("Pearson correlation:",data["precipitation"].corr(data["temp_max"]))

print("T Test and P value:",stats.ttest_ind(data["precipitation"],data["temp_max"]))
# Out:
# Pearson correlation: -0.22855481643297004
# T Test and P value: Ttest_indResult(statistic=-71.30132077496027, pvalue=0.0)

# %%
data.plot("wind","temp_max",style='o') 
print("Pearson correlation:",data["wind"].corr(data["temp_max"]))
print("T Test and P value:",stats.ttest_ind(data["wind"],data["temp_max"]))
# Out:
# Pearson correlation: -0.16485663487495497
# T Test and P value: Ttest_indResult(statistic=-26.094454222214207, pvalue=4.221164387998153e-135)

# %%
data.plot("temp_max","temp_min",style='o')
# Out:
# <Axes: xlabel='temp_max'>

# %%
data.isna().sum()
# Out:
# date             0
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %%
pip install missingno
# Out:
# Collecting missingno
#   Using cached missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from missingno) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from missingno) (3.7.0)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from missingno) (1.10.0)
# Requirement already satisfied: seaborn in c:\users\user\anaconda3\lib\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\user\anaconda3\lib\site-packages (from seaborn->missingno) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as mso

# %%
plt.figure(figsize=(12,6))
axz=plt.subplot(1,2,2)
mso.bar(data.drop(["date"],axis=1),ax=axz,fontsize=12);

# %%
data = data.drop(["date"],axis=1)

# %%
Q1=data.quantile(0.25)
Q3=data.quantile(0.75)
IQR=Q3-Q1
df=data[~((data<(Q1-1.5*IQR))|(data>(Q3+1.5*IQR))).any(axis=1)]

# %%
sns.set(style="darkgrid")
fig,axs=plt.subplots(2,2,figsize=(10,8))
sns.histplot(data=df,x="precipitation",kde=True,ax=axs[0,0],color='green')
sns.histplot(data=df,x="temp_max",kde=True,ax=axs[0,1],color='red')
sns.histplot(data=df,x="temp_min",kde=True,ax=axs[1,0],color='skyblue')
sns.histplot(data=df,x="wind",kde=True,ax=axs[1,1],color='orange')
# Out:
# <Axes: xlabel='wind', ylabel='Count'>

# %%
df.head()
# Out:
#    precipitation  temp_max  temp_min      wind  weather
# 0       0.000000  0.387097  0.476378  0.472527  drizzle
# 2       0.014311  0.357527  0.562992  0.208791     rain
# 4       0.023256  0.282258  0.389764  0.626374     rain
# 5       0.044723  0.161290  0.366142  0.197802     rain
# 6       0.000000  0.236559  0.389764  0.208791     rain

# %%
lc=LabelEncoder()
df["weather"]=lc.fit_transform(df["weather"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 lc=LabelEncoder()
#       2 df["weather"]=lc.fit_transform(df["weather"])
#
# NameError: name 'LabelEncoder' is not defined

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.head()
# Out:
#    precipitation  temp_max  temp_min      wind  weather
# 0       0.000000  0.387097  0.476378  0.472527  drizzle
# 2       0.014311  0.357527  0.562992  0.208791     rain
# 4       0.023256  0.282258  0.389764  0.626374     rain
# 5       0.044723  0.161290  0.366142  0.197802     rain
# 6       0.000000  0.236559  0.389764  0.208791     rain

# %%
df.head()
# Out:
#    precipitation  temp_max  temp_min      wind  weather
# 0       0.000000  0.387097  0.476378  0.472527  drizzle
# 2       0.014311  0.357527  0.562992  0.208791     rain
# 4       0.023256  0.282258  0.389764  0.626374     rain
# 5       0.044723  0.161290  0.366142  0.197802     rain
# 6       0.000000  0.236559  0.389764  0.208791     rain

# %%
x=((df.loc[:,df.columns!="weather"]).astype(int)).values[:,0:]
y=df["weather"].values

# %%
df.weather.unique()
# Out:
# array(['drizzle', 'rain', 'sun', 'snow', 'fog'], dtype=object)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=2)
#
# NameError: name 'train_test_split' is not defined

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
print("KNN Accuracy:{:.2f}%".format(knn.score(x_test,y_test)*100))
# Out:
# KNN Accuracy:57.09%

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()

# %%
svm=SVC()
svm.fit(x_train,y_train)
print("SVM Accuracy:{:.2f}%".format(svm.score(x_test,y_test)*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 svm=SVC()
#       2 svm.fit(x_train,y_train)
#       3 print("SVM Accuracy:{:.2f}%".format(svm.score(x_test,y_test)*100))
#
# NameError: name 'SVC' is not defined

# %%
from sklearn.svm import SVC

# %%
gbc=GradientBoostingClassifier(subsample=0.5,n_estimators=450,max_depth=5,max_leaf_nodes=25)
gbc.fit(x_train,y_train)
print("Gradient Boosting Accuracy:{:.2f}%".format(gbc.score(x_test,y_test)*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 gbc=GradientBoostingClassifier(subsample=0.5,n_estimators=450,max_depth=5,max_leaf_nodes=25)
#       2 gbc.fit(x_train,y_train)
#       3 print("Gradient Boosting Accuracy:{:.2f}%".format(gbc.score(x_test,y_test)*100))
#
# NameError: name 'GradientBoostingClassifier' is not defined

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
import warnings
warnings.filterwarnings('ignore')
xgb=XGBClassifier()
xgb.fit(x_train,y_train)
print("XGB Accuracy:{:.2f}%".format(xgb.score(x_test,y_test)*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 import warnings
#       2 warnings.filterwarnings('ignore')
# ----> 3 xgb=XGBClassifier()
#       4 xgb.fit(x_train,y_train)
#       5 print("XGB Accuracy:{:.2f}%".format(xgb.score(x_test,y_test)*100))
#
# NameError: name 'XGBClassifier' is not defined

# %%
from xgboost import XGBClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 from xgboost import XGBClassifier
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
pip install xgboost

# %%
input=[[10.140175,10.9,2.8,4.469818]]
ot=xgb.predict(input)
print("The weather is:")
if(ot==0):
    print("Drizzle")
elif(ot==1):
    print("Fog")
elif(ot==2):
    print("Rain")
elif(ot==3):
    print("snow")
else:
    print("Sun")

# %%
# Calculate the Pearson correlation matrix
pearson_corr_matrix = data.corr(method='pearson')

# Print the Pearson correlation matrix
print(pearson_corr_matrix)

# %%
spearman_corr_matrix = data.corr(method='spearman')
print(spearman_corr_matrix)

# %%
import numpy as np
from scipy import stats


# Perform one-sample t-test
t_statistic, p_value = stats.ttest_1samp(x_test, 2)

# Print results
print("t-statistic:", t_statistic)
print("p-value:", p_value)

# %%
import scipy.stats as stats

groups = data.groupby("weather")

# Get the temperature max values for each group
temp_min = [group["temp_max"] for name, group in groups]

# Perform one-way ANOVA test
f_val, p_val = stats.f_oneway(*temp_min)

# Print the results
print("F-value:", f_val)
print("p-value:", p_val)
